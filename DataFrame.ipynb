# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard() # show the copied material *super useful

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North
# 5              1966   AFC East

# %%
nfl_frame.columns # show each column
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Team #object name.column name shows what the column has.
# Out:
# 0          Dallas Cowboys
# 1       Green Bay Packers
# 2        Baltimore Ravens
# 3    New England Patriots
# 4           Chicago Bears
# 5          Miami Dolphins
# Name: Team, dtype: object

# %%
nfl_frame['First NFL season'] # if a column has more than one word, use [] brakets.and
# Out:
# 0    1960
# 1    1921
# 2    1996
# 3    1960
# 4    1920
# 5    1966
# Name: First NFL season, dtype: int64

# %%
DataFrame(nfl_frame,columns = ['Rank','Team','Won','Lost','Place']) # if the argument has a column that doesn't exist
# it shows like below
# Out:
#    Rank                  Team  Won  Lost  Place
# 0     1        Dallas Cowboys  550   408    NaN
# 1     2     Green Bay Packers  790   590    NaN
# 2     3      Baltimore Ravens  243   190    NaN
# 3     4  New England Patriots  537   420    NaN
# 4     5         Chicago Bears  786   624    NaN
# 5     6        Miami Dolphins  485   393    NaN

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North
# 5              1966   AFC East

# %%
nfl_frame.head(2) #show first 5 rows without argument inside ()
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL season  \
# 0     1     Dallas Cowboys    964  550   408     6  0.574              1960
# 1     2  Green Bay Packers  1,418  790   590    38  0.571              1921
#
#     Division
# 0   NFC East
# 1  NFC North

# %%
nfl_frame.tail(2) #show the last the number of () rows
# Out:
#    Rank            Team     GP  Won  Lost  Tied   Pct.  First NFL season  \
# 4     5   Chicago Bears  1,452  786   624    42  0.556              1920
# 5     6  Miami Dolphins    882  485   393     4  0.552              1966
#
#     Division
# 4  NFC North
# 5   AFC East

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North
# 5              1966   AFC East

# %%
nfl_frame.ix[3] # ix for "index"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 nfl_frame.ix[3]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
nfl_frame['Stadium'] = "Levi's Stadium" #fill the the same column by [xxx]

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1996  AFC North  Levi's Stadium
# 3              1960   AFC East  Levi's Stadium
# 4              1920  NFC North  Levi's Stadium
# 5              1966   AFC East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(6) #check the number of valid rows

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division  Stadium
# 0              1960   NFC East        0
# 1              1921  NFC North        1
# 2              1996  AFC North        2
# 3              1960   AFC East        3
# 4              1920  NFC North        4
# 5              1966   AFC East        5

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadiuam"],index = [2,0])

# %%
stadiums # assign the series
# Out:
# 2    Levi's Stadium
# 0     AT&T Stadiuam
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums 
# based on the assigned series, Levi's is 2 and AT&T is now 0

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division         Stadium
# 0              1960   NFC East   AT&T Stadiuam
# 1              1921  NFC North             NaN
# 2              1996  AFC North  Levi's Stadium
# 3              1960   AFC East             NaN
# 4              1920  NFC North             NaN
# 5              1966   AFC East             NaN

# %%
del nfl_frame['Stadium'] # delete the specific column

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    964  550   408     6  0.574
# 1     2     Green Bay Packers  1,418  790   590    38  0.571
# 2     3      Baltimore Ravens    434  243   190     1  0.561
# 3     4  New England Patriots    966  537   420     9  0.561
# 4     5         Chicago Bears  1,452  786   624    42  0.556
# 5     6        Miami Dolphins    882  485   393     4  0.552
#
#    First NFL season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1996  AFC North
# 3              1960   AFC East
# 4              1920  NFC North
# 5              1966   AFC East

# %%
data = {'City':['SF','LA','NYC'],'Population':[837000,3880000,840000],'State':['CA','CA','NY']}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population State
# 0   SF      837000    CA
# 1   LA     3880000    CA
# 2  NYC      840000    NY
