# %%
import pandas as pd
import statistics as st

# %%
homeprice_df = pd.read_excel("/Users/schoolsoftware/Documents/wd/ITEC620/dataset/HomePrices.xlsx")

# %%
print(homeprice_df)
# Out:
#      Size (sq. ft.)  Age (years)  School Rating (0-10)  \
# 0              1784            8                     7
# 1              4500           50                    10
# 2              1334           84                     5
# 3              3205           12                     7
# 4              3165           86                     8
# ..              ...          ...                   ...
# 345            1023           75                     8
# 346            3880            1                     9
# 347            3257           61                     7
# 348            4055           47                     8
# 349            1015           63                     6
#
#      Violent Crime Rate (# per 100,000 people per year)  Sale Price
# 0                                                  411       395000
# 1                                                  411      1221000
# 2                                                  635       238000
# ...

# %%
pd.tail(homeprice_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sg/mfby51qn5fq0_rpdw52b6ln00000gp/T/ipykernel_11066/2744495792.py in <module>
# ----> 1 pd.tail(homeprice_df)
#
# /Users/ryotanaka/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'tail'

# %%
homeprice_df.head()
# Out:
#    Size (sq. ft.)  Age (years)  School Rating (0-10)  \
# 0            1784            8                     7
# 1            4500           50                    10
# 2            1334           84                     5
# 3            3205           12                     7
# 4            3165           86                     8
#
#    Violent Crime Rate (# per 100,000 people per year)  Sale Price
# 0                                                411       395000
# 1                                                411      1221000
# 2                                                635       238000
# 3                                                488      1013000
# 4                                                411       818000

# %%
homeprice_df.tail()
# Out:
#      Size (sq. ft.)  Age (years)  School Rating (0-10)  \
# 345            1023           75                     8
# 346            3880            1                     9
# 347            3257           61                     7
# 348            4055           47                     8
# 349            1015           63                     6
#
#      Violent Crime Rate (# per 100,000 people per year)  Sale Price
# 345                                                306       286000
# 346                                                306      1100000
# 347                                                411       946000
# 348                                                635      1088000
# 349                                                306       226000

# %%
homeprice_df[0:5]
# Out:
#    Size (sq. ft.)  Age (years)  School Rating (0-10)  \
# 0            1784            8                     7
# 1            4500           50                    10
# 2            1334           84                     5
# 3            3205           12                     7
# 4            3165           86                     8
#
#    Violent Crime Rate (# per 100,000 people per year)  Sale Price
# 0                                                411       395000
# 1                                                411      1221000
# 2                                                635       238000
# 3                                                488      1013000
# 4                                                411       818000

# %%
homeprice_df[:5]
# Out:
#    Size (sq. ft.)  Age (years)  School Rating (0-10)  \
# 0            1784            8                     7
# 1            4500           50                    10
# 2            1334           84                     5
# 3            3205           12                     7
# 4            3165           86                     8
#
#    Violent Crime Rate (# per 100,000 people per year)  Sale Price
# 0                                                411       395000
# 1                                                411      1221000
# 2                                                635       238000
# 3                                                488      1013000
# 4                                                411       818000

# %%
homeprice_df.mean(axis = 1,
                  skipna = True,
                  )
# Out:
#      Size (sq. ft.)  Age (years)  School Rating (0-10)  \
# 0              1784            8                     7
# 1              4500           50                    10
# 2              1334           84                     5
# 3              3205           12                     7
# 4              3165           86                     8
# ..              ...          ...                   ...
# 345            1023           75                     8
# 346            3880            1                     9
# 347            3257           61                     7
# 348            4055           47                     8
# 349            1015           63                     6
#
#      Violent Crime Rate (# per 100,000 people per year)  Sale Price
# 0                                                  411       395000
# 1                                                  411      1221000
# 2                                                  635       238000
# ...
