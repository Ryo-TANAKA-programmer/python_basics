# %%
import numpy as np

from pandas import Series,DataFrame

import pandas as pd

# %%
pip install --upgrade pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr
from datetime import datetime
data = pdr.get_data_yahoo('^GSPC', datetime(1970, 1, 1))
print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import pandas_datareader as pdr
#       2 from datetime import datetime
# ----> 3 data = pdr.get_data_yahoo('^GSPC', datetime(1970, 1, 1))
#       4 print()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
# ...

# %%
# this one works: someone from Reddit provided this code for me.

import pandas_datareader.data as pdr
import yfinance as yf
yf.pdr_override()
import datetime as dt
data = pdr.get_data_yahoo('WMT', datetime(2022, 1, 1))
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  144.000000  144.789993  143.009995  144.649994  142.411392
# 2022-01-04  144.039993  145.139999  141.759995  142.000000  139.802414
# 2022-01-05  142.850006  145.949997  142.740005  143.919998  141.692688
# 2022-01-06  143.619995  144.639999  142.399994  143.520004  141.298904
# 2022-01-07  143.500000  145.360001  142.960007  144.889999  142.647675
# ...                ...         ...         ...         ...         ...
# 2023-01-09  146.320007  147.860001  144.800003  144.949997  144.949997
# 2023-01-10  144.940002  145.449997  143.729996  144.860001  144.860001
# 2023-01-11  145.740005  146.179993  144.729996  146.130005  146.130005
# 2023-01-12  146.410004  146.419998  144.389999  144.809998  144.809998
# 2023-01-13  145.529999  145.820007  143.860001  145.289993  145.289993
#
#               Volume
# Date
# ...

# %%
# I watched this video but the code provided in the video didn't work...

from IPython.display import YouTubeVideo 
YouTubeVideo('sgndYho8RyI')

# %%
ticker = 'WMT'

# %%
start = dt.datetime(2022,1,1)
end = dt.datetime(2023,1,1)
data = pdr.get_data_yahoo(ticker,start,end)
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  144.000000  144.789993  143.009995  144.649994  142.411392
# 2022-01-04  144.039993  145.139999  141.759995  142.000000  139.802399
# 2022-01-05  142.850006  145.949997  142.740005  143.919998  141.692673
# 2022-01-06  143.619995  144.639999  142.399994  143.520004  141.298889
# 2022-01-07  143.500000  145.360001  142.960007  144.889999  142.647675
#
#               Volume
# Date
# 2022-01-03   6902200
# 2022-01-04  11310000
# 2022-01-05  11806000
# 2022-01-06   7276300
# 2022-01-07   6574500

# %%
data.index
# Out:
# DatetimeIndex(['2022-01-03', '2022-01-04', '2022-01-05', '2022-01-06',
#                '2022-01-07', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14',
#                ...
#                '2022-12-30', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11',
#                '2023-01-12', '2023-01-13'],
#               dtype='datetime64[ns]', name='Date', length=260, freq=None)

# %%
data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-23  143.050003  143.800003  142.279999  143.770004  143.770004
# 2022-12-27  144.039993  144.449997  143.190002  143.809998  143.809998
# 2022-12-28  143.470001  143.669998  140.910004  141.289993  141.289993
# 2022-12-29  142.139999  143.020004  141.750000  142.149994  142.149994
# 2022-12-30  141.559998  141.990005  140.809998  141.789993  141.789993
#
#              Volume
# Date
# 2022-12-23  3182500
# 2022-12-27  3348200
# 2022-12-28  5082100
# 2022-12-29  3057300
# 2022-12-30  3834800

# %%
data2 = pdr.get_data_stooq(ticker,start,end) # shows most recent data first
data2.head() 
data2.tail()
nasdaq_sym = pdr.get_nasdaq_symbols()
nasdaq_sym
# Out:
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
# ...               ...                                                ...
# ZXYZ.A           True                 Nasdaq Symbology Test Common Stock
# ZXZZT            True                                  NASDAQ TEST STOCK
# ZYME             True                      Zymeworks Inc. - Common Stock
# ZYNE             True       Zynerba Pharmaceuticals, Inc. - Common Stock
# ZYXI             True                         Zynex, Inc. - Common Stock
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# ...

# %%
len(nasdaq_sym) # how many?
